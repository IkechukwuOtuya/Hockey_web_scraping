# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Ikechukwu\Downloads\PYTHON TRAINING\countries of the world (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   Region   227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
df2 = df['Country']

# %%
df2
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                        American Samoa
# 4                               Andorra
# 5                                Angola
# 6                              Anguilla
# 7                     Antigua & Barbuda
# 8                             Argentina
# 9                               Armenia
# 10                                Aruba
# 11                            Australia
# 12                              Austria
# 13                           Azerbaijan
# 14                         Bahamas, The
# 15                              Bahrain
# 16                           Bangladesh
# 17                             Barbados
# 18                              Belarus
# 19                              Belgium
# 20                               Belize
# 21                                Benin
# 22                              Bermuda
# ...

# %%
df
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
df.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df2 = df

# %%
df2
# Out:
#                                Country                               Region
# 0                         Afghanistan         ASIA (EX. NEAR EAST)
# 1                             Albania   EASTERN EUROPE
# 2                             Algeria   NORTHERN AFRICA
# 3                      American Samoa   OCEANIA
# 4                             Andorra   WESTERN EUROPE
# 5                              Angola   SUB-SAHARAN AFRICA
# 6                            Anguilla               LATIN AMER. & CARIB
# 7                   Antigua & Barbuda               LATIN AMER. & CARIB
# 8                           Argentina               LATIN AMER. & CARIB
# 9                             Armenia                  C.W. OF IND. STATES
# 10                              Aruba               LATIN AMER. & CARIB
# 11                          Australia   OCEANIA
# 12                            Austria   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# ...

# %%
df2.loc[45]
# Out:
# Country                      Congo, Dem. Rep.
# Region     SUB-SAHARAN AFRICA
# Name: 45, dtype: object

# %%
df2.iloc[8]
# Out:
# Country                 Argentina
# Region     LATIN AMER. & CARIB
# Name: 8, dtype: object

# %%
df3 = pd.read_csv(r"C:\Users\Ikechukwu\Downloads\PYTHON TRAINING\world_population.csv")

# %%
df3[df3['Rank'] < 10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %%
specific_countries = ['Nigeria', 'Russia']

# %%
df3[df3['Country'].isin(specific_countries)]
# Out:
#      Rank CCA3  Country Capital Continent  2022 Population  2020 Population  \
# 149     6  NGA  Nigeria   Abuja    Africa      218541212.0      208327405.0
# 171     9  RUS   Russia  Moscow    Europe      144713314.0      145617329.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 149      183995785.0      160952853.0      122851984.0       95214257.0
# 171      144668389.0      143242599.0      146844839.0      148005704.0
#
#      1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 149       72951439.0       55569264.0    923768.0           236.5759
# 171      138257420.0      130093010.0  17098242.0             8.4636
#
#      Growth Rate  World Population Percentage
# 149       1.0241                         2.74
# 171       0.9973                         1.81

# %%
df3[df3['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df = df3.set_index('Country')

# %%
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
df.filter(items = ['Continent', 'CCA3'], axis = 0)
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
df.filter(items = ['Nigeria'], axis = 0)
# Out:
#          Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Nigeria     6  NGA   Abuja    Africa      218541212.0      208327405.0
#
#          2015 Population  2010 Population  2000 Population  1990 Population  \
# Nigeria      183995785.0      160952853.0      122851984.0       95214257.0
#
#          1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Nigeria       72951439.0       55569264.0    923768.0           236.5759
#
#          Growth Rate  World Population Percentage
# Nigeria       1.0241                         2.74

# %%
df.loc['Nigeria']
# Out:
# Rank                                     6
# CCA3                                   NGA
# Capital                              Abuja
# Continent                           Africa
# 2022 Population                218541212.0
# 2020 Population                208327405.0
# 2015 Population                183995785.0
# 2010 Population                160952853.0
# 2000 Population                122851984.0
# 1990 Population                 95214257.0
# 1980 Population                 72951439.0
# 1970 Population                 55569264.0
# Area (km²)                        923768.0
# Density (per km²)                 236.5759
# Growth Rate                         1.0241
# World Population Percentage           2.74
# Name: Nigeria, dtype: object

# %%
df.iloc[2]
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                               Country  Rank CCA3              Capital  \
# 0                         Afghanistan    36  AFG                Kabul
# 1                             Albania   138  ALB               Tirana
# 2                             Algeria    34  DZA              Algiers
# 3                      American Samoa   213  ASM            Pago Pago
# 4                             Andorra   203  AND     Andorra la Vella
# 5                              Angola    42  AGO               Luanda
# 6                            Anguilla   224  AIA           The Valley
# 7                 Antigua and Barbuda   201  ATG         Saint John’s
# 8                           Argentina    33  ARG         Buenos Aires
# 9                             Armenia   140  ARM              Yerevan
# 10                              Aruba   198  ABW           Oranjestad
# 11                          Australia    55  AUS             Canberra
# ...

# %%
df.set_index('Country', inplace = True)

# %%
df
# Out:
#                                   Rank CCA3              Capital  \
# Country
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                               Country  Rank CCA3              Capital  \
# 0                         Afghanistan    36  AFG                Kabul
# 1                             Albania   138  ALB               Tirana
# 2                             Algeria    34  DZA              Algiers
# 3                      American Samoa   213  ASM            Pago Pago
# 4                             Andorra   203  AND     Andorra la Vella
# 5                              Angola    42  AGO               Luanda
# 6                            Anguilla   224  AIA           The Valley
# 7                 Antigua and Barbuda   201  ATG         Saint John’s
# 8                           Argentina    33  ARG         Buenos Aires
# 9                             Armenia   140  ARM              Yerevan
# 10                              Aruba   198  ABW           Oranjestad
# 11                          Australia    55  AUS             Canberra
# ...

# %%
df.set_index(['Continent','Country'], inplace = True)

# %%
df.sort_index(ascending = True)
# Out:
#                                                 Rank CCA3  \
# Continent     Country
# Africa        Algeria                             34  DZA
#               Angola                              42  AGO
#               Benin                               77  BEN
#               Botswana                           144  BWA
#               Burkina Faso                        58  BFA
#               Burundi                             78  BDI
#               Cameroon                            53  CMR
#               Cape Verde                         171  CPV
#               Central African Republic           117  CAF
#               Chad                                69  TCD
#               Comoros                            163  COM
#               DR Congo                            15  COD
#               Djibouti                           160  DJI
#               Egypt                               14  EGY
#               Equatorial Guinea                  152  GNQ
# ...

# %%
group = df.groupby('Continent')

# %%
df9 = group.count()

# %%
import numpy as np

# %%
df.plot()
# Out:
# <Axes: xlabel='Continent,Country'>
